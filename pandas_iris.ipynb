# %%
import pandas as pd

# %%
df=pd.read_csv("Iris.csv")    
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            NaN           2.3
# 146  147            NaN           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#print all the rows from the dataset
#pd.set_option('display.max_rows', 150)
#df

# %%
print(df.head(7))     #selecting first five rows from the dataset
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa

# %%
print(df.tail(5))    #selecting last five rows from the dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            NaN           2.3
# 146  147            NaN           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
print(df.info())    #info of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  148 non-null    float64
#  2   SepalWidthCm   147 non-null    float64
#  3   PetalLengthCm  146 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
print(df.describe()) #description of dataset
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     148.000000    147.000000     146.000000    150.000000
# mean    75.500000       5.845270      3.052381       3.717808      1.198667
# std     43.445368       0.830567      0.437041       1.770006      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.525000      0.300000
# 50%     75.500000       5.800000      3.000000       4.250000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
(df.sample(6))      #randomly selecting specified number of rows or fraction of rows from the dataframe
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 123  124            6.3           2.7            NaN           1.8
# 9     10            4.9           3.1            1.5           0.1
# 59    60            5.2           2.7            3.9           1.4
# 63    64            6.1           2.9            4.7           1.4
# 36    37            5.5           3.5            1.3           0.2
# 13    14            4.3           3.0            1.1           0.1
#
#              Species
# 123   Iris-virginica
# 9        Iris-setosa
# 59   Iris-versicolor
# 63   Iris-versicolor
# 36       Iris-setosa
# 13       Iris-setosa

# %%
#Handling the missing values in the dataset:
#removing rows with any missing values
#df.dropna(inplace=True)
#df

# %%
#Replace the missing value with 0(zero)
#df.fillna(value=0,inplace=True)
#df

# %%
#Remove duplicate rows
#df.drop_duplicates(inplace=True)
#df

# %%
#Rename column ({'OldName': 'NewName'}
# inplace=True replaces the original column without creating a new variable to store the column or dataframe
df.rename(columns={"SepalLengthCm":"SepallongCm"}, inplace=True)
df
#df.rename(columns={"SepalLengthCm":"SepalLongCm"}, {"SepalWidthCm":"SepalThicknessCm"}, inplace=True)
#df
# Out:
#       Id  SepallongCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          5.1           3.5            1.4           0.2
# 1      2          4.9           3.0            1.4           0.2
# 2      3          4.7           3.2            1.3           0.2
# 3      4          4.6           3.1            1.5           0.2
# 4      5          5.0           3.6            1.4           0.2
# ..   ...          ...           ...            ...           ...
# 145  146          6.7           3.0            0.0           2.3
# 146  147          0.0           2.5            5.0           1.9
# 147  148          6.5           3.0            5.2           2.0
# 148  149          6.2           3.4            5.4           2.3
# 149  150          5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %%
#checking dataframe after cleaning
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepallongCm    150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
#saving cleaned data to a new csv file  #we need to pass the second argument,index=false to avoid new unnamed column of index values in the new csv dataframe
df.to_csv('New Iris.csv',index=False)

# %%
df2=pd.read_csv('New Iris.csv')
df2
# Out:
#       Id  SepallongCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          5.1           3.5            1.4           0.2
# 1      2          4.9           3.0            1.4           0.2
# 2      3          4.7           3.2            1.3           0.2
# 3      4          4.6           3.1            1.5           0.2
# 4      5          5.0           3.6            1.4           0.2
# ..   ...          ...           ...            ...           ...
# 145  146          6.7           3.0            0.0           2.3
# 146  147          0.0           2.5            5.0           1.9
# 147  148          6.5           3.0            5.2           2.0
# 148  149          6.2           3.4            5.4           2.3
# 149  150          5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %%
missing_values=df2.isnull().sum()  
print(missing_values)
# Out:
# Id               0
# SepallongCm      0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
selected_col=df['PetalLengthCm']  #selecting specific column
selected_col
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    0.0
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
filtered_df=df[df['PetalLengthCm']>5]
filtered_df
# Out:
#       Id  SepallongCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 83    84          6.0           2.7            5.1           1.6
# 100  101          6.3           3.3            6.0           2.5
# 101  102          5.8           2.7            5.1           1.9
# 102  103          7.1           3.0            5.9           2.1
# 103  104          6.3           2.9            5.6           1.8
# 104  105          6.5           3.0            5.8           2.2
# 105  106          7.6           3.0            6.6           2.1
# 107  108          7.3           2.9            6.3           1.8
# 108  109          6.7           2.5            5.8           1.8
# 109  110          7.2           3.6            6.1           2.5
# 110  111          6.5           3.2            5.1           2.0
# 111  112          6.4           2.7            5.3           1.9
# 112  113          6.8           3.0            5.5           2.1
# ...

# %%
#mean
mean_values= df['SepalWidthCm'].mean()
mean_values
# Out:
# 3.0523809523809526

# %%
mean_values= df['PetalWidthCm']. mean()
mean_values
# Out:
# 1.1986666666666668

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    2
# SepalWidthCm     3
# PetalLengthCm    4
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
mean_values= df['SepalLengthCm']. mean()
mean_values
# Out:
# 5.8452702702702695

# %%
mean_values= df['PetalLengthCm']. mean()
mean_values
# Out:
# 3.7178082191780817

# %%
df.fillna(value= mean_values, inplace= True)    #Replacing the null values with their respective mean_values.
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1       5.100000           3.5       1.400000           0.2
# 1      2       4.900000           3.0       1.400000           0.2
# 2      3       4.700000           3.2       1.300000           0.2
# 3      4       4.600000           3.1       1.500000           0.2
# 4      5       5.000000           3.6       1.400000           0.2
# ..   ...            ...           ...            ...           ...
# 145  146       6.700000           3.0       3.717808           2.3
# 146  147       3.717808           2.5       5.000000           1.9
# 147  148       6.500000           3.0       5.200000           2.0
# 148  149       6.200000           3.4       5.400000           2.3
# 149  150       5.900000           3.0       5.100000           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#checking dataframe again after replacing the none with mean_values
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
